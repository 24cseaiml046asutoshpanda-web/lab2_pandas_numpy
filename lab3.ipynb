# %%
# !pip install matplotlib sklearn
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
# ...

# %% [markdown]
# ### Question

# %% [markdown]
# WAP to implement simple linear regration using machine learning techniques to predict values based on a given dataset
# using 1 depemdent and 1 indepemdent variable
#
# read the dataset containing 2 columns independent variable x and dependent dataset y

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv('test.csv')

X = dataset.iloc[ : ,   : 1 ].values
Y = dataset.iloc[ : , 1 ].values
print(dataset.info())
print(dataset.describe())
print(dataset.isnull().sum())
# from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size = 1/4, random_state = 0) 

print(X_test[:5],"\n\n\n",X_train[:5],"\n",Y_test[:5],"\n",Y_test[:5])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       300 non-null    int64
#  1   y       300 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 4.8 KB
# None
#                 x           y
# count  300.000000  300.000000
# mean    50.936667   51.205051
# std     28.504286   29.071481
# min      0.000000   -3.467884
# 25%     27.000000   25.676502
# 50%     53.000000   52.170557
# 75%     73.000000   74.303007
# max    100.000000  105.591837
# x    0
# y    0
# dtype: int64
# [[ 67]
#  [ 27]
#  [ 96]
#  [100]
#  [ 28]]
#
#
#  [[36]
#  [69]
#  [87]
#  [73]
#  [30]]
#  [ 68.48820749  30.49412933  95.14907176 103.5266162   28.15668543]
#  [ 68.48820749  30.49412933  95.14907176 103.5266162   28.15668543]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor = regressor.fit(X_train, Y_train)

# %%
Y_pred = regressor.predict(X_test)
print(Y_pred[:10])
# Out:
# [ 67.41740179  26.79618917  96.86778093 100.92990219  27.81171949
#   65.38634115  36.95149233  39.99808327  52.18444706  89.75906872]

# %%
plt.scatter(X_train , Y_train, color = 'red')
plt.plot(X_train , regressor.predict(X_train), color ='blue')

# %%
plt.scatter(X_test , Y_test, color = 'red')
plt.plot(X_test , regressor.predict(X_test), color ='blue')

# %%
# write a program to create a numpy array and pwrform array indexing and clicing
# write a program to create numpy array and perform matrix multiplication
# wite a program  to find min and max avg min and avg max
# wap to concatinate and stacking
# wap to element wise comparision 
# wap to create a array 
# wap to crate a numpy array and calculate like addition and multiplecation and

# %%
import numpy as np 

arr1 = np.array([[1,2,3,4,5,6],[1,5,4,1,4,6]])
arr2 = np.array([[1,2,3,4,5,6],[9,7,8,5,6,4]])
print(arr1+arr2)
print()
print(arr1*arr2)

print(arr1.diagonal())

print(arr1==arr2)
# Out:
# [[ 2  4  6  8 10 12]
#  [10 12 12  6 10 10]]
#
# [[ 1  4  9 16 25 36]
#  [ 9 35 32  5 24 24]]
# [1 5]
# [[ True  True  True  True  True  True]
#  [False False False False False False]]

# %%
np.concatenate((arr1,arr2), axis=1)
# Out:
# array([[1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6],
#        [1, 5, 4, 1, 4, 6, 9, 7, 8, 5, 6, 4]])

# %%
print(np.max(arr1))
print(np.max(arr2))
print(np.min(arr1))
print(np.min(arr2))
# Out:
# 6
# 9
# 1
# 1
